# %% [markdown]
# # Coder of bangalore
# You ask Sam Altman for a 2.2 billion USD Iin funding and he makes fun of you in public.
#
# He asks you where you liv and finally after talking to you, give you a challenging task
#
# Collect raw data instagram data of all openai followers
#
# Answer there Question:
#    - who has maximum posts
#    - who has maximum followers
#    - who follows maximum people
#    - who many categories (digital creators, Non profit foundation etc do we have) of how many people do we have
#
# You have 24 hours
#
# You then ask for data - he laughs!

# %% [markdown]
# # Data Collection
# You hire Vijaylaxmi Iyer and Sam Chandra who are from Herbal and HSR Layout respectively

# %%
with open("finaldata.txt", encoding = 'utf-8') as f:
    data = f.read()

# %%
data
# Out:
# "techie_koramangala\n420 posts\n9,800 followers\n310 following\nArjun M.\nSoftware Engineer\n💻 Full-stack @ SaaS startup\n☕ Working from cafes in Koramangala\ngithub.com/arjunmakes\n\nblrcoder_girl\n150 posts\n6,300 followers\n120 following\nRiya Codes\nTech Creator\n👩\u200d💻 Python | ML | Roadmaps\n🎥 Coding Reels + Daily Motivation\nlinktr.ee/riyacodes\n\nhsr_startup_stories\n980 posts\n22.4K followers\n95 following\nStartup Stories HSR\nMedia\n🚀 Interviews with Bangalore founders\n🎙️ Weekly startup breakdowns\nhsrstartupstories.com\n\ncloud_dev_blr\n210 posts\n4,500 followers\n60 following\nNaveen DevOps\nEngineer\n☁️ AWS | Docker | K8s\n📍 Sarjapur\ngithub.com/naveencloud\n\nkoramangala_coffee_lover\n300 posts\n7,900 followers\n180 following\nSana B.\nCafe Explorer\n☕ Reviewing Bangalore’s hidden coffee spots\n📍 Koramangala\nyoutube.com/@sanacafehunter\n\nai_bangalore_news\n1,340 posts\n38K followers\n200 following\nAI Bangalore\nMedia\n🤖 Daily AI news from India\n📢 Startup & resea
# ...

# %%
chunks  =  data.split("\n\n")

# %%
chunks = [c for c in chunks if len(c)>3]
chunks
# Out:
# ['techie_koramangala\n420 posts\n9,800 followers\n310 following\nArjun M.\nSoftware Engineer\n💻 Full-stack @ SaaS startup\n☕ Working from cafes in Koramangala\ngithub.com/arjunmakes',
#  'blrcoder_girl\n150 posts\n6,300 followers\n120 following\nRiya Codes\nTech Creator\n👩\u200d💻 Python | ML | Roadmaps\n🎥 Coding Reels + Daily Motivation\nlinktr.ee/riyacodes',
#  'hsr_startup_stories\n980 posts\n22.4K followers\n95 following\nStartup Stories HSR\nMedia\n🚀 Interviews with Bangalore founders\n🎙️ Weekly startup breakdowns\nhsrstartupstories.com',
#  'cloud_dev_blr\n210 posts\n4,500 followers\n60 following\nNaveen DevOps\nEngineer\n☁️ AWS | Docker | K8s\n📍 Sarjapur\ngithub.com/naveencloud',
#  'koramangala_coffee_lover\n300 posts\n7,900 followers\n180 following\nSana B.\nCafe Explorer\n☕ Reviewing Bangalore’s hidden coffee spots\n📍 Koramangala\nyoutube.com/@sanacafehunter',
# ...

# %%
def parse_chunk(chunk):
            chunk = chunk.strip()
            sep_chunk = chunk.split("\n")
            username = sep_chunk[0]
            no_of_posts = int(sep_chunk[1].split(" post")[0].replace(",",""))
            no_of_follower = float(sep_chunk[2].split(" follower")[0].replace(",","").replace("K","").replace("M",""))
            if ("K" in sep_chunk[2]):
                no_of_follower = int(no_of_follower * 1000)
            elif ("M" in sep_chunk[2]):
                no_of_follower =  int(no_of_follower * 1000000)
            else:
                no_of_follower = int(no_of_follower)
                
            no_of_following = float(sep_chunk[3].split(" following")[0].replace(",","").replace("M","").replace("K",""))
            if ("M" in sep_chunk[3]):
                no_of_following = int(no_of_following * 1000000)
            elif("K" in sep_chunk[3]):
                no_of_following = int(no_of_following * 1000 )
            else:
                no_of_following = int(no_of_following)
            name =  sep_chunk[4]
            if(len(sep_chunk) > 5):
                type_of_page = sep_chunk[5]
                bio ="\n".join(sep_chunk[6:])
            else:
                type_of_page =  "Unknown"
                bio = ""
            # print(username, no_of_follower, no_of_following, name, type_of_page,bio, sep = '\n')
            return {"username":username,"no_of_posts":no_of_posts,"no_of_follower":no_of_follower,"no_of_following":no_of_following,"name":name,"type_of_page":type_of_page,"bio":bio}

# %%
all_chunks = []
for chunk in chunks:
    parsed_chunk = parse_chunk(chunk)
    all_chunks.append(parsed_chunk)
# print(all_chunks)

# %%
for chunk in all_chunks:
    print(chunk["type_of_page"])
# Out:
# Software Engineer
# Tech Creator
# Media
# Engineer
# Cafe Explorer
# Media
# Founder
# Backend Developer
# Media
# Frontend Dev
# Lifestyle
# Food & Drink
# Community
# Full-stack Dev
# Community
# Media
# Blog
# Community
# Artist + Coder
# Product Manager
# Community
# Recruiter
# Developer
# Design
# Cafe Nerd
# Engineer
# Media
# Media
# Blog
# Tech Creator
# Lifestyle
# Community
# Media
# Education
# Developer
# Coder
# Lifestyle
# Community
# Education
# Community
# Comedy
# Design
# Data Science
# Data Scientist
# Education
# Community
# Nonprofit organization
# Digital creator
# Blogger
# Entrepreneur
# Public Figure
# Media
# Food & Drink
# Investor
# Community
# Personal Blog
# Media
# Personal Blog
# Community
# Community
# Tech
# Community
# Media
# Educator
# Community
# Community
# Community
# Blog
# Tech
# Personal Blog
# Community
# Community
# Community
# Community
# Blog
# Community
# Public Figure
# Community
# Personal Blog
# Community
# Blog
# Community
# ...

# %%
import json
s = json.dumps(all_chunks, indent = 4)
with open('data.json','w') as f:
    f.write()

# %% [markdown]
# ## Who has the maximum posts ?
#  Lets write code to find max posts

# %%
max = 0 
for chunk in all_chunks:
    if(max < chunk["no_of_posts"]):
        max = chunk["no_of_posts"]
        chunk_with_max_post = chunk
print(f"The maximum posts username: {chunk_with_max_post['username']} and total post: {chunk_with_max_post["no_of_posts"]}")
# Out:
# The maximum posts username: startuphub_blr and total post: 2300

# %% [markdown]
# ## Who has the maximum followers ?
#  Let's write code to find max fllowers

# %%
max = 0 
maximum_follower = 0
for chunk in all_chunks:
    if max < chunk["no_of_follower"]:
        max = chunk["no_of_follower"]
        maximum_follower = chunk
print(f"The maximum followers username: {maximum_follower["username"]} and total followers: {maximum_follower["no_of_follower"]}")
# Out:
# The maximum followers username: _anujsinghal and total followers: 681000

# %% [markdown]
# ## who follows maximum people
# Let's write code to find who has follow maximum  people

# %%
max  = 0
for chunk in all_chunks:
    if max < chunk['no_of_following']:
        max = chunk['no_of_following']
        maximum_follow_people = chunk
print(f"Follows maximum people username: \"{maximum_follow_people["username"]}\" and total followed people: {maximum_follow_people["no_of_following"]}")
# Out:
# Follows maximum people username: "bangalore_tech_bro" and total followed people: 890

# %% [markdown]
# ## who many categories (digital creators, Non profit foundation etc do we have) of how many people do we have
# Let's write code to find out numberof categories

# %%
categories =  set()
for chunk in all_chunks:
    categories.add(chunk['type_of_page'])
print(f"All categories: {categories},Their are {len(categories)} categories.")
# Out:
# All categories: {'Full-stack Dev', 'Blogger', 'Personal Blog', 'Comedy', 'Public Figure', 'Backend Developer', 'Software Engineer', 'Founder', 'Recruiter', 'Food & Drink', 'Data Science', 'Artist + Coder', 'Writer', 'Investor', 'Nonprofit organization', 'Developer', 'Community', 'Tech Creator', 'Design', 'Data Scientist', 'Digital creator', 'Entrepreneur', 'Tech', 'Coder', 'Product Manager', 'Blog', 'Cafe Explorer', 'Frontend Dev', 'Education', 'Cafe Nerd', 'Lifestyle', 'Engineer', 'Educator', 'Media'},Their are 34 categories.
